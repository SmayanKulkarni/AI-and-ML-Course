# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/smayan/Desktop/AI-ML-DS/BootCamp/new_preprocessed_loan_data_day2.csv")
df
# Out:
#         Unnamed: 0  Loan_Amount  Interest_Rate  Installment  Terms(Months)  \
# 0                0       5000.0          10.65       162.87             36
# 1                1       2500.0          15.27        59.83             60
# 2                2       2400.0          15.96        84.33             36
# 3                3      10000.0          13.49       339.31             36
# 4                4       5000.0           7.90       156.46             36
# ...            ...          ...            ...          ...            ...
# 266024      277135       4200.0          15.99       147.64             36
# 266025      277136      10775.0           6.03       327.95             36
# 266026      277137       6225.0          16.49       220.37             36
# 266027      277138       4000.0           8.67       126.59             36
# 266028      277139      10850.0          19.24       399.04             36
#
# ...

# %% [markdown]
# # Feature Engineering

# %%
df.head(5)
# Out:
#    Unnamed: 0  Loan_Amount  Interest_Rate  Installment  Terms(Months)  \
# 0           0       5000.0          10.65       162.87             36
# 1           1       2500.0          15.27        59.83             60
# 2           2       2400.0          15.96        84.33             36
# 3           3      10000.0          13.49       339.31             36
# 4           4       5000.0           7.90       156.46             36
#
#    Employment_Length Home_Ownership  Annual_Income  Debt_to_Income_Ratio  \
# 0               10.0           RENT        24000.0                 27.65
# 1                0.5           RENT        30000.0                  1.00
# 2               10.0           RENT        12252.0                  8.72
# 3               10.0           RENT        49200.0                 20.00
# 4                3.0           RENT        36000.0                 11.20
#
#   Verification_Status  ... Public_Record Total_Accounts  \
# ...

# %%
df.shape
# Out:
# (266029, 24)

# %%
df['Verification_Status'].unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266029 entries, 0 to 266028
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                266029 non-null  int64
#  1   Loan_Amount               266029 non-null  float64
#  2   Interest_Rate             266029 non-null  float64
#  3   Installment               266029 non-null  float64
#  4   Terms(Months)             266029 non-null  int64
#  5   Employment_Length         255367 non-null  float64
#  6   Home_Ownership            266029 non-null  object
#  7   Annual_Income             266029 non-null  float64
#  8   Debt_to_Income_Ratio      266029 non-null  float64
#  9   Verification_Status       266029 non-null  object
#  10  Grade                     266029 non-null  object
#  11  Sub_Grade                 266029 non-null  object
#  12  Delinquency_2yrs          266029 non-null  float64
# ...

# %%
df['Verification Status'] = df['Verification_Status'].replace('Source Verified', 'Verified')

# %%
df = df[df['Home_Ownership']!='NONE']
df = df[df['Home_Ownership']!='ANY']

# %%
df['Home_Ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
df.shape
# Out:
# (265985, 25)

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df['Terms(Months)'].value_counts()
# Out:
# Terms(Months)
# 36    203737
# 60     62248
# Name: count, dtype: int64

# %%
columms_to_drop = ['Delinquency_2yrs', 'Total_Accounts','Sub_Grade','Total_Received_Principal','Total_Received_Interest',
                   'Loan_Status', 'Issue_Month','Issue_Year', 'region','Public_Record', 'Annual_Income']
df.drop(columns=columms_to_drop)
df.columns
# Out:
# Index(['Loan_Amount', 'Interest_Rate', 'Installment', 'Terms(Months)',
#        'Employment_Length', 'Home_Ownership', 'Annual_Income',
#        'Debt_to_Income_Ratio', 'Verification_Status', 'Grade', 'Sub_Grade',
#        'Delinquency_2yrs', 'Open_Accounts', 'Public_Record', 'Total_Accounts',
#        'Total_Received_Principal', 'Total_Received_Interest', 'Purpose',
#        'Loan_Status', 'Issue_Month', 'Issue_Year', 'region', 'Risk_Category',
#        'Verification Status'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Loan_Amount  Interest_Rate  Installment  Terms(Months)  Employment_Length  \
# 0        5000.0          10.65       162.87             36               10.0
# 1        2500.0          15.27        59.83             60                0.5
# 2        2400.0          15.96        84.33             36               10.0
# 3       10000.0          13.49       339.31             36               10.0
# 4        5000.0           7.90       156.46             36                3.0
# 5        3000.0          18.64       109.43             36                9.0
# 6        5600.0          21.28       152.39             60                4.0
# 7        5375.0          12.69       121.45             60                0.5
# 8        6500.0          14.65       153.45             60                5.0
# 9       12000.0          12.69       402.54             36               10.0
# 10       9000.0          13.49       305.38             36                0.5
# ...

# %%
df.columns
# Out:
# Index(['Loan_Amount', 'Interest_Rate', 'Installment', 'Terms(Months)',
#        'Employment_Length', 'Home_Ownership', 'Annual_Income',
#        'Debt_to_Income_Ratio', 'Verification_Status', 'Grade', 'Sub_Grade',
#        'Delinquency_2yrs', 'Open_Accounts', 'Public_Record', 'Total_Accounts',
#        'Total_Received_Principal', 'Total_Received_Interest', 'Purpose',
#        'Loan_Status', 'Issue_Month', 'Issue_Year', 'region', 'Risk_Category',
#        'Verification Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

nominal_columns = ['Purpose']
df = pd.get_dummies(df, columns=nominal_columns)

# %%
df.head()
# Out:
#    Loan_Amount  Interest_Rate  Installment  Terms(Months)  Employment_Length  \
# 0       5000.0          10.65       162.87             36               10.0
# 1       2500.0          15.27        59.83             60                0.5
# 2       2400.0          15.96        84.33             36               10.0
# 3      10000.0          13.49       339.31             36               10.0
# 4       5000.0           7.90       156.46             36                3.0
#
#   Home_Ownership  Annual_Income  Debt_to_Income_Ratio Verification_Status  \
# 0           RENT        24000.0                 27.65            Verified
# 1           RENT        30000.0                  1.00     Source Verified
# 2           RENT        12252.0                  8.72        Not Verified
# 3           RENT        49200.0                 20.00     Source Verified
# 4           RENT        36000.0                 11.20     Source Verified
#
# ...
